# %% [markdown]
# # Combining Individual Files
# ```{admonition} Adding Files
# In the `.html` file, list all the questionnaire files you will be using in the following format:</br>
# <img src="../_images/PictureC1.png" style="width: 70%;">
# ```
#
# ```{admonition} Adding Questionnaire Blocks
# If you don't need to show different content to different participants, you can add each
# questionnaire block here directly (and you're almost done!):
# <img src="../_images/PictureC2.png" style="width: 70%;">
#
# Participants will see the questionnaires in the exact order the blocks are listed here.
# ```

# %% [markdown]
# ```{important}
# For the Safety Learning Project, participants above and below 18 years old are shown different versions of the questionnaires. An extra step is involved to achieve this (see [Some Other Settings](../JSPsych/other_things.ipynb)).
# ```
