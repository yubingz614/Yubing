# %% [markdown]
# # Modifying an Individual File
# ## Creating a Likert Scale Block
#
# ```{admonition} Instruction
# Using **2a. DASSY_likert_block.js** as an example, the first few lines in the file create an instruction page displayed to participants:
# <img src="../_images/PictureIF1.png" style="width: 100%;">
#
# What participants see:</br>
# <img src="../_images/PictureIF2.png" style="width: 60%;">
#
# To create your own questionnaire block, modify the instruction text here:
# <img src="../_images/PictureIF3.png" style="width: 100%;">
#
# To adjust font, size, text alignment, and other styling:
# <img src="../_images/PictureIF4.png" style="width: 100%;">
# ```
#
# ```{admonition} Page Navigation
# To allow the participants to proceed to the next page:
# <img src="../_images/PictureIF5.png" style="width: 100%;">
#
# Other options for proceeding include:</br>
# <img src="../_images/PictureIF6.png" style="width: 50%;">
# ```
#
# ```{admonition} Questions & Responses
# The response choices and questions are defined here:
# <img src="../_images/PictureIF7.png" style="width: 80%;">
#
# What participants see:</br>
# <img src="../_images/PictureIF8.png" style="width: 50%;">
#
# Since all questions in this questionnaire share the same response options, they only need to be defined once in a chunk called `scale` (you can use any name, but keep it consistent throughout the file), and then referenced for each individual question:
# <img src="../_images/PictureIF9.png" style="width: 80%;">
#
# If response options differ across questions, define them separately within the `var questions` chunk (see **"16b. SSPDG_likert_block.js"** for an example):
# <img src="../_images/PictureIF10.png" style="width: 80%;">
# ```
#
# ```{admonition} Additional Settings
# <img src="../_images/PictureIF11.png" style="width: 90%;">
# ```

# %% [markdown]
# ## Other Types of Surveys & Functions
# Here are some examples beyond the Likert scale:
#
# ```{admonition} Drop-down Menu
#  Example: **1. demographics_block.js**
# <img src="../_images/PictureIF12.png" style="width: 80%;">
#
# What participants see:</br>
# <img src="../_images/PictureIF13.png" style="width: 60%;">
# ```
#
# ```{admonition} Text Response
# Example: **1. demographics_block.js**
# <img src="../_images/PictureIF14.png" style="width: 80%;">
#
# What participants see:</br>
# <img src="../_images/PictureIF15.png" style="width: 25%;">
# ```
#
# ```{admonition} Presenting an Image
# Example: **0. consent_block.js**
# <img src="../_images/PictureIF16.png" style="width: 90%;">
# ```
#
# ```{admonition} Other JSPsych Functions
# For other JSPsych functions, including slider, multi-select, and audio/video, are documented on the [JSPsych Website](https://www.jspsych.org/7.3/).
# ```

# %% [markdown]
# ```{important}
# The `survey-html-form` plugin allows you to mix different question types on the same page.
# ```
