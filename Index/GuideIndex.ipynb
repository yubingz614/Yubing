# %% [markdown]
# # AND LAB Research Guides 🧠
#
# Welcome!! This is a resource originally created for the AND Lab at the University of Melbourne. These guides cover the key tools and methods we use in the lab, and are designed to help you get started.
#
# Feel free to explore, and don't hesitate to reach out to Yubing (yubingz@student.unimelb.edu.au) if anything is unclear.

# %% [markdown]
# [Coding and Data Wrangling 101 Guide](https://andlabunimelb.github.io/ANDLab_Guides/Coding/intro.html)
#
# [JSPsych & Pavlovia Guide](https://andlabunimelb.github.io/ANDLab_Guides/Questionnaire/intro.html)
#
# [Neuroimaging Data Conversion & Preprocessing Guide](https://andlabunimelb.github.io/ANDLab_Guides/fMRI_Preprocessing/intro.html)

# %% [markdown]
# > Version 1.0.0. Yubing Zhang. Mar 2026.
