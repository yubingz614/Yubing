# %% [markdown]
# # Uploading for Data Collection
# For the Safety Learning Project, we used a platform called [Pavlovia](https://pavlovia.org/) for data collection. To make it work on the platform, you'll need to add the following codes before and after your questionnaire blocks in the `html` file:
#
# <img src="../_images/PictureU1.png" style="width: 50%;">

# %% [markdown]
# ```{important}
# After adding these lines, the `.html` file can no longer be opened directly in your browser. Therefore, it is recommended to finalise everything else before doing so. See [Pushing Questionnaires to Pavlovia](../Pavlovia/pavlovia.ipynb) for instructions on how to use the platform.
# ```
