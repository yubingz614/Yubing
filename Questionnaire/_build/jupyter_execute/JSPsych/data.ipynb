# %% [markdown]
# # What the Data Will Look Like
# You will get one Excel file per participant:
# <img src="../_images/PictureD1.png" style="width: 100%;">

# %% [markdown]
# ```{important}
# All answers collected on a single page will be stored in one cell, so make sure each question is meaningfully labelled.
#
# A negative example where labels were not added:
# <img src="../_images/PictureD2.png" style="width: 80%;">
#
# A better example:
# <img src="../_images/PictureD3.png" style="width: 80%;">
# ```

# %% [markdown]
# ![](./images/5/2.png)

# %% [markdown]
# ![](./images/5/3.png)
