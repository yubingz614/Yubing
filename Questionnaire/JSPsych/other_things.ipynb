# %% [markdown]
# # Some Other Settings
# ```{admonition} Making Questions Required
# For Likert scale and text response surveys, you can add **required: true** directly after the individual question (see **demographics_block.js** as an example).
# <img src="../_images/PictureO1.png" style="width: 90%;">
#
# You can add the following codes at the end to ensure all the questions within the block are answered (see **2a. DASSY_likert_block.js** as an example).
# <img src="../_images/PictureO2.png" style="width: 90%;">
#
# For drop-down box, it needs to be modified in the **jspsych-survey-select.js** file in the **jspsych** folder and then the **plugins** folder.
# <img src="../_images/PictureO3.png" style="width: 90%;">
# ```
#
# ```{admonition} Enforcing the Correct Answering Format
# You can also ask the participants to fill in digits only (or digits with a certain length) in surveys with text response:
# <img src="../_images/PictureO4.png" style="width: 95%;">
# ```

# %% [markdown]
# ```{admonition} Adding Conditional Questions
# Follow these steps to ask participants additional questions based on their answers. Using **16b. SSPDG_likert_block.js** as an example:
#
# 1. The initial question:
# <img src="../_images/PictureO5.png" style="width: 85%;">
# </br></br>
# 2. Create a new question block (called **"SSPDG6b"** here) for the additional question:
# <img src="../_images/PictureO6.png" style="width: 95%;">
# </br></br>
# 3. Retrieve the participant's answer to the initial question:
# <img src="../_images/PictureO7.png" style="width: 90%;">
# </br></br>
# 4. Determine whether to show the additional question:
# <img src="../_images/PictureO8.png" style="width: 60%;">
# </br></br>
# 5. Add the new block to the timeline at the end:</br>
# <img src="../_images/PictureO9.png" style="width: 40%;">
# ```

# %% [markdown]
# ```{admonition} Participant-Specific Questionnaires
# Use the following steps to assign questionnaires based on participant characteristics.
#
# 1.  Decide how to categorise your participants. In the Safety Learning project, we use age (above or below 18) and sex (male or female), captured in the demographic questionnaire at the start of the survey.
# <img src="../_images/PictureO10.png" style="width: 90%;">
# </br></br>
# 2. To retrieve relevant answers from **"1. demographics_block.js"**, create a global variable for each category.
# <img src="../_images/PictureO11.png" style="width: 90%;">
#
# Then save the corresponding answers into those variables.
# <img src="../_images/PictureO12.png" style="width: 90%;">
#
# 3. Assign different questionnaires to different participant categories:
# <img src="../_images/PictureO13.png" style="width: 100%;">
# ```
